# %% [markdown]
# # Experiment template\n\nThis notebook shows the bootstrap and autoreload patterns for the project.\n

# %%
# Optional bootstrap if this notebook is not using the project kernel\nimport sys\nfrom pathlib import Path\n\nROOT = Path.cwd().resolve().parent\nSRC = ROOT / 'src'\nif str(SRC) not in sys.path:\n    sys.path.insert(0, str(SRC))\n

# %%
# %load_ext autoreload\n%autoreload 2\n

# %%
from {{ cookiecutter.package_name }}.paths import data_dir, repo_root\n\nprint(repo_root())\nprint(data_dir('raw'))\n
